# %%
# Program to check if year entered is a leap year
# defining the leap year function
def is_leap_yr():
  year=int(input("Please enter the year: "))
  if (year % 4 == 0) and (year % 100 != 0):
    print(" Year is leap year.")
  elif (year % 400 == 0 and year % 100 == 0):
    print(" Year is leap year.")
  else:
    print ("Year is not leap year")

# calling the function
is_leap_yr()
# Out:
# Please enter the year: 2016
#  Year is leap year.

# %%
# Program for cms to inches convertor
# defining the convertor function
def convertor():
  cms=int(input("Please enter the value to convert in cms: "))
  inches=cms/2.54
  print(inches)

# calling the function
convertor()
# Out:
# Please enter the value to convert in cms: 100
# 39.37007874015748
