# %%
name=input("Enter your name: ")
#i=j=len(name)
x=len(name)
for i in range(0,x):
  for j in range(0,x):
    if i==j:
      print(name[i],end=" ")
    else:
      print("*",end=" ")
  print(" ")
# Out:
# Enter your name: Hemalatha
# H * * * * * * * *
# * e * * * * * * *
# * * m * * * * * *
# * * * a * * * * *
# * * * * l * * * *
# * * * * * a * * *
# * * * * * * t * *
# * * * * * * * h *
# * * * * * * * * a
