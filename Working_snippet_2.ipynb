# %%
# Slicing few ingredients out from sandwich ingredients

sandwich_ingre=["Bread", "Butter", "Cheese", "pepper", "salt", "onion", "capsicum", "Boiled potatoes", "cucumber", "carrots"]
print ("All sandwich ingredients", sandwich_ingre)
print ("Only Vegetables ", sandwich_ingre[5:9])
print ("Other ingredients ",sandwich_ingre[-10:-5])
sandwich_ingre[0:10:3] #the last part is slicing with step give the interval number,this lists every 3rd item
# Out:
# All sandwich ingredients ['Bread', 'Butter', 'Cheese', 'pepper', 'salt', 'onion', 'capsicum', 'Boiled potatoes', 'cucumber', 'carrots']
# Only Vegetables  ['onion', 'capsicum', 'Boiled potatoes', 'cucumber']
# Other ingredients  ['Bread', 'Butter', 'Cheese', 'pepper', 'salt']
# ['Bread', 'pepper', 'capsicum', 'carrots']

# %%
# Use slicing functionality to extract only marks from the below list of subjects and marks

Sub_with_mark = ["English", 75 , "Science", 80, "Maths", 95, "CS", 82, "Social", 68]
print ("Printing only marks", Sub_with_mark[1:2], "||", Sub_with_mark[3:4], "||", Sub_with_mark[5:6], "||", Sub_with_mark[7:8], "||", Sub_with_mark[9:10])
# Correction after the discussion in the class
Sub_with_mark[1:10:2]
# Out:
# Printing only marks [75] || [80] || [95] || [82] || [68]
# [75, 80, 95, 82, 68]
