# %%
#Program to print all the numbers in the range entered which are divisible by x (any number)

x=int(input("Enter the divisible number "))
r1=int(input("Enter the start range "))
r2=int(input("Enter the stop range "))
for i in range(r1,r2):
  if i%x==0:
    print(i)
# Out:
# Enter the divisible number 20
# Enter the start range 0
# Enter the stop range 200
# 0
# 20
# 40
# 60
# 80
# 100
# 120
# 140
# 160
# 180
