# %% [markdown]
# Create a class for rating movies you can use attributes like movie name, story rating, music rating, actors rating and overall avg rating

# %%
#Define class

class movie_details:
  # define attribute of class
  def __init__(self,name,story_rating,actor_rating,music_rating,overall_avg_rating):
    self.movie_name=name
    self.story_rating=story_rating
    self.actor_rating=actor_rating
    self.music_rating=music_rating
    self.overall_avg_rating=overall_avg_rating


  # define methods of the class


    self.movie= {
        "name": self.movie_name,
        "storyrating":self.story_rating,
        "actorrating": self.actor_rating,
        "musicrating":self.music_rating,
        "overallavgrating":self.overall_avg_rating
        }


  def view_movie_details(self,movie_list):
    print(movie_list)


  def add_movie_details( self,movie_list):
    movie_list.append(self.movie)


movierate_list=[]
#n=len(movierate_list)
#create an object
new_movie=movie_details("Leo",6,8,8,8)
new_movie.add_movie_details(movierate_list)

new_movie=movie_details("Alaipayuthey",6,8,8,10)
new_movie.add_movie_details(movierate_list)

new_movie=movie_details("Mouna Ragam",6,8,8,10)
new_movie.add_movie_details(movierate_list)

new_movie=movie_details("Minsara Kanavu",6,8,8,7)
new_movie.add_movie_details(movierate_list)

new_movie=movie_details("Kannathil Muthamittai",6,8,8,9)
new_movie.add_movie_details(movierate_list)

new_movie.view_movie_details(movierate_list)
# Out:
# [{'name': 'Leo', 'storyrating': 6, 'actorrating': 8, 'musicrating': 8, 'overallavgrating': 8}, {'name': 'Alaipayuthey', 'storyrating': 6, 'actorrating': 8, 'musicrating': 8, 'overallavgrating': 10}, {'name': 'Mouna Ragam', 'storyrating': 6, 'actorrating': 8, 'musicrating': 8, 'overallavgrating': 10}, {'name': 'Minsara Kanavu', 'storyrating': 6, 'actorrating': 8, 'musicrating': 8, 'overallavgrating': 7}, {'name': 'Kannathil Muthamittai', 'storyrating': 6, 'actorrating': 8, 'musicrating': 8, 'overallavgrating': 9}]
